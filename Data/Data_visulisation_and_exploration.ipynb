# 3   2006-12-06  29.10  29.13  28.87  28.99      28.99    0.9003  0.051  0.847
# 4   2006-12-07  28.96  29.07  28.81  28.85      28.85    0.6597  0.000  0.810
# 5   2006-12-08  28.82  29.40  28.80  29.40      29.40    0.0000  0.000  0.000
# 6   2006-12-11  29.19  29.75  29.11  29.54      29.54    0.0000  0.000  0.000
# 7   2006-12-12  29.56  29.63  29.22  29.43      29.43    0.0000  0.000  1.000
# 8   2006-12-13  29.60  29.60  29.32  29.55      29.55    0.5574  0.000  0.833
# 9   2006-12-14  29.54  30.08  29.52  30.07      30.07    0.0000  0.000  0.000
# 10  2006-12-15  30.14  30.23  30.03  30.19      30.19    0.1260  0.048  0.868
# ...

# %% [markdown]
# #### store the data into a variable

# %%
micro=pd.read_csv('MicrosoftFinalData.csv')
apple=pd.read_csv('AppleFinalData.csv')

# %% [markdown]
# #### Prepocess the data

# %%
apple=apple.rename(columns={'Adj Close':'Price'})   # reaname the column
apple=apple.drop('Close',axis=1)                    # remove the unused column
apple['Month']=int                                  # add a blank month column in the data field
# add the data into the month column, it will take time
for i in range(len(apple)):
    apple['Month'][i]=int(apple['Date'][i].split('-')[1])
# arrange the final sequence of column
apple=apple[['Open', 'High', 'Low', 'compound', 'neg', 'neu', 'pos','Month','Date','Price']]   
apple.columns   # check the finla output
# Out:
# /Users/batman/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Index(['Open', 'High', 'Low', 'compound', 'neg', 'neu', 'pos', 'Month', 'Date',
#        'Price'],
#       dtype='object')

# %%
# process the colums of the file
micro=micro.rename(columns={'Adj Close':'Price'})   # reaname the column
micro=micro.drop('Close',axis=1)                    # remove the unused column
micro['Month']=int                                  # add a blank month column in the data field

# add the data into the month column, it will take time
for i in range(len(micro)):
  micro['Month'][i]=int(micro['Date'][i].split('-')[1])

# arrange the final sequence of column
micro=micro[['Open', 'High', 'Low', 'compound', 'neg', 'neu', 'pos','Month','Date','Price']]   
micro.columns   # check the finla output
# Out:
# /Users/batman/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Index(['Open', 'High', 'Low', 'compound', 'neg', 'neu', 'pos', 'Month', 'Date',
#        'Price'],
#       dtype='object')

# %% [markdown]
# ### Split and Normalize the data

# %%
# split the data
m_stock=micro.iloc[:,:3].values
m_news=micro.iloc[0:,3:7].values
# normalize the data
for i in [0,1,2]:
    m_stock[:,i]=(m_stock[:,i]-np.min(m_stock[:,i]))/(np.max(m_stock[:,i])-np.min(m_stock[:,i]))

# %%
# split the data
a_news=apple.iloc[0:,3:7].values
a_stock=apple.iloc[:,:3].values
# normalize the stock data
for i in [0,1,2]:
    a_stock[:,i]=(a_stock[:,i]-np.min(a_stock[:,i]))/(np.max(a_stock[:,i])-np.min(a_stock[:,i]))

# %% [markdown]
# ### Apple and Microsoft closing price

# %%
# %matplotlib inline
fig=plt.figure(figsize=(15, 8), dpi= 80, facecolor='w', edgecolor='k')

index = [pd.to_datetime(date, format='%Y-%m-%d').date() for date in apple['Date']]

plt.plot(index ,apple['Price'], label='apple')
plt.plot(index ,micro['Adj Close'], label='microsoft')
plt.legend()
plt.grid()
_ = plt.ylim()

# %% [markdown]
# ### Normalized data and Raw stock data

# %%
fig=plt.figure(figsize=(15, 12), dpi= 80, facecolor='w', edgecolor='k')

index = [pd.to_datetime(date, format='%Y-%m-%d').date() for date in apple['Date']]
# graph 1
ax1=plt.subplot2grid((8,1),(0,0),rowspan=3,colspan=1)
ax1.plot(index,apple['Open'],label='Raw open')
plt.xlabel('Date')
plt.ylabel('Raw stock')
ax1.grid()
# graph 2
ax2=plt.subplot2grid((8,1),(3,0),rowspan=3,colspan=1)
ax2.plot(index,a_stock[:,0],label='Normalized open',color='red')
ax2.grid()
plt.xlabel('Date')
plt.ylabel('Normalized stock')

plt.show()

# %% [markdown]
# ### To see the effect of news on stock price

# %%
fig=plt.figure(figsize=(15, 12), dpi= 80, facecolor='w', edgecolor='k')

d=2477

ax1=plt.subplot2grid((8,1),(0,0),rowspan=5,colspan=1)
ax1.plot(index[d:],stock[d:,0],label='Raw open')
plt.xlabel('Date')
plt.ylabel('Raw stock')
ax1.grid()


# ax2=plt.subplot2grid((8,1),(3,0),rowspan=3,colspan=1)
ax2=ax1.twinx()
# ax2.plot(index[d:],news[d:,0],label='Normalized open',color='red',linewidth=1)
ax2.fill_between(index[d:],news[d:,0],alpha=0.3)

ax2.grid()
plt.xlabel('Date')
plt.ylabel('Compound value of News')
plt.legend()

plt.show()
# Out:
# /Users/batman/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# ### Plot to show the training/ validataion/testing proportions.
#
# #### for apple

# %%
# %matplotlib inline
fig=plt.figure(figsize=(15, 8), dpi= 80, facecolor='w', edgecolor='k')

index = [pd.to_datetime(date, format='%Y-%m-%d').date() for date in apple['Date']]

plt.plot(index[:1829] ,stock[:1829,0], label='train')
plt.plot(index[1829:1829+209] ,stock[1829:1829+209,0], label='validate')
plt.plot(index[1829+209:] ,stock[1829+209:,0], label='test')
plt.xlabel('Date')
plt.ylabel('Adj Close or Price')
plt.legend()
plt.grid()
_ = plt.ylim()

# %% [markdown]
# ####  for microsoft

# %%
# %matplotlib inline
fig=plt.figure(figsize=(15, 8), dpi= 80, facecolor='w', edgecolor='k')

index = [pd.to_datetime(date, format='%Y-%m-%d').date() for date in apple['Date']]

plt.plot(index[:1829] ,m_stock[:1829,0], label='train')
plt.plot(index[1829:1829+209] ,m_stock[1829:1829+209,0], label='validate')
plt.plot(index[1829+209:] ,m_stock[1829+209:,0], label='test')
plt.xlabel('Date')
plt.ylabel('Adj Close or Price')
plt.legend()
plt.grid()
_ = plt.ylim()
